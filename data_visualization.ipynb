# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
sample_data = pd.read_csv("sample_data.csv")

# %%
x = [2, 4, 8]
y = [5, 10, 15]
z = [15, 10 , 5]
plt.plot(x, y)
plt.plot(x, z)
plt.title("Test")
plt.xlabel("x")
plt.ylabel("y and z")
plt.legend(["this is y", "this is z"])
plt.show()

# %%
plt.plot(sample_data.column_a, sample_data.column_b)
plt.plot(sample_data.column_a, sample_data.column_c)
plt.show()

# %%
type(sample_data)
# Out:
# pandas.core.frame.DataFrame

# %%
data = pd.read_csv("countries.csv")

# %%
# comparing population of india and usa

# %%
india = data[data.country == 'India']

# %%
us = data[data.country == 'United States']

# %%
plt.plot(us.year, us.population/10**6)
plt.plot(india.year, india.population/10**6)
plt.title("India and USA population anlaysis")
plt.xlabel("Year")
plt.ylabel("USA and India")
plt.legend(["USA", "India"])
plt.show()

# %%
plt.plot(us.year, us.population/us.population.iloc[0]*100)
plt.plot(india.year, india.population/india.population.iloc[0]*100)
plt.title("India and USA population growth anlaysis")
plt.xlabel("Year")
plt.ylabel("USA and India")
plt.legend(["USA", "India"])
plt.show()
